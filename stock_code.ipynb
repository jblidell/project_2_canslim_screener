# %%
# Required Libraries
import pandas as pd
import numpy as np
from pathlib import Path
import hvplot.pandas
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from pandas.tseries.offsets import DateOffset
from sklearn.metrics import classification_report
import fundamentalanalysis as fa
import os
from dotenv import load_dotenv
from stocksymbol import StockSymbol

# %%
load_dotenv()
# Out:
# True

# %%
fa_api_key = os.getenv("FA_API_KEY")
ss_api_key = os.getenv("STOCK_SYMBOL")

# %%
ss = StockSymbol(ss_api_key)

# %%
symbols = ss.get_symbol_list(market="US")

# %%
symbols_df = pd.DataFrame(symbols, columns=['symbol', 'shortName', 'longName', 'exchange', 'market', 'quoteType'])

# %%
symbols_df.head()
# Out:
#   symbol  shortName               longName exchange     market quoteType
# 0   AAPL      apple             Apple Inc.   NASDAQ  us_market    EQUITY
# 1   MSFT  microsoft  Microsoft Corporation   NASDAQ  us_market    EQUITY
# 2   GOOG   alphabet          Alphabet Inc.   NASDAQ  us_market    EQUITY
# 3  GOOGL   alphabet          Alphabet Inc.   NASDAQ  us_market    EQUITY
# 4   AMZN     amazon       Amazon.com, Inc.   NASDAQ  us_market    EQUITY

# %%
fr_apple = fa.financial_ratios('AAPL', fa_api_key)

# %%
fs_apple = fa.financial_statement_growth('AAPL', fa_api_key)
fs_apple
# Out:
#                                             2021      2020       2019  \
# period                                        FY        FY         FY
# revenueGrowth                           0.332594  0.055121  -0.020411
# grossProfitGrowth                       0.456191  0.066713  -0.033848
# ebitgrowth                               0.64357  0.036884  -0.098282
# operatingIncomeGrowth                    0.64357  0.036884  -0.098282
# netIncomeGrowth                         0.649161     0.039  -0.071811
# epsgrowth                               0.712991  0.106099  -0.003331
# epsdilutedGrowth                        0.710366  0.103448  -0.001679
# weightedAverageSharesGrowth            -0.037508 -0.060592  -0.068117
# weightedAverageSharesDilutedGrowth     -0.037842 -0.057403  -0.070238
# dividendsperShareGrowth                 0.067451  0.061635   0.104947
# operatingCashFlowGrowth                  0.28961    0.1626  -0.103869
# freeCashFlowGrowth                      0.266994   0.24567  -0.081487
# tenYRevenueGrowthPerShare               4.236507  5.176488   8.639399
# fiveYRevenueGrowthPerShare              1.222795  0.557805   0.875697
# threeYRevenueGrowthPerShare             0.634674  0.440242    0.42939
# tenYOperatingCFGrowthPerShare           3.295628  5.366885   8.246367
# fiveYOperatingCFGrowthPerShare          1.070955  0.316614   0.531431
# threeYOperatingCFGrowthPerShare         0.594584  0.525593   0.248915
# tenYNetIncomeGrowthPerShare             4.659674  5.012479  12.113508
# fiveYNetIncomeGrowthPerShare            1.715367  0.426055   0.843043
# threeYNetIncomeGrowthPerShare           0.887566  0.428033   0.432851
# tenYShareholdersEquityGrowthPerShare    0.275993  1.006393   3.401144
# fiveYShareholdersEquityGrowthPerShare  -0.355431 -0.273952   0.069045
# threeYShareholdersEquityGrowthPerShare -0.301176 -0.413776  -0.164106
# tenYDividendperShareGrowthPerShare           0.0       0.0        0.0
# fiveYDividendperShareGrowthPerShare     0.560145  0.615369   0.672353
# threeYDividendperShareGrowthPerShare    0.252174  0.326249   0.376708
# receivablesGrowth                       0.375511 -0.182495  -0.065129
# inventoryGrowth                         0.620291  -0.01096   0.037917
# assetGrowth                             0.083714 -0.043212  -0.074397
# bookValueperShareGrowth                 0.003208 -0.231352  -0.093747
# debtGrowth                              0.109244  0.040621  -0.056218
# rdexpenseGrowth                         0.168622  0.156317   0.139154
# sgaexpensesGrowth                            0.0       0.0        0.0
#
#                                              2018       2017       2016  \
# period                                         FY         FY         FY
# revenueGrowth                             0.15862   0.063045  -0.077342
# grossProfitGrowth                         0.15482   0.046557  -0.100004
# ebitgrowth                               0.155745   0.021991  -0.157321
# operatingIncomeGrowth                    0.155745   0.021991  -0.157321
# netIncomeGrowth                          0.231226    0.05831  -0.144342
# epsgrowth                                0.295577    0.11018  -0.100216
# epsdilutedGrowth                          0.29316   0.108303  -0.098698
# weightedAverageSharesGrowth             -0.050192  -0.046351  -0.049119
# weightedAverageSharesDilutedGrowth      -0.047905  -0.045196  -0.050541
# dividendsperShareGrowth                  0.130598   0.102027   0.105235
# operatingCashFlowGrowth                  0.217554  -0.033817  -0.190018
# freeCashFlowGrowth                        0.26215  -0.028177  -0.250824
# tenYRevenueGrowthPerShare                9.183715  10.077175  11.057312
# fiveYRevenueGrowthPerShare               1.031285   0.837074   1.355821
# threeYRevenueGrowthPerShare              0.319419   0.462767   0.493835
# tenYOperatingCFGrowthPerShare            9.049176  12.487328  31.022055
# fiveYOperatingCFGrowthPerShare            0.88604   0.568503   1.074226
# threeYOperatingCFGrowthPerShare          0.106298   0.242324   0.452204
# tenYNetIncomeGrowthPerShare             14.336474  15.043673  23.807087
# fiveYNetIncomeGrowthPerShare             1.100999   0.453148   1.084313
# threeYNetIncomeGrowthPerShare            0.294494   0.427443   0.460493
# tenYShareholdersEquityGrowthPerShare     5.344972   9.700436  12.872902
# fiveYShareholdersEquityGrowthPerShare    0.133598   0.422286   0.979607
# threeYShareholdersEquityGrowthPerShare   0.042291   0.401715   0.229016
# tenYDividendperShareGrowthPerShare            0.0        0.0        0.0
# fiveYDividendperShareGrowthPerShare      0.696645   5.437106        0.0
# threeYDividendperShareGrowthPerShare     0.377066   0.338685   0.361729
# receivablesGrowth                        0.373448    0.21755  -0.034407
# inventoryGrowth                          -0.18517   1.277205   -0.09238
# assetGrowth                             -0.025562   0.166725   0.107433
# bookValueperShareGrowth                 -0.158436    0.09601   0.130023
# debtGrowth                              -0.010348   0.329166   0.350129
# rdexpenseGrowth                          0.229255   0.152912   0.245196
# sgaexpensesGrowth                             0.0        0.0        0.0
#
#                                              2015        2014        2013  \
# period                                         FY          FY          FY
# revenueGrowth                            0.278563     0.06954    0.092021
# grossProfitGrowth                        0.327332     0.09693    -0.06347
# ebitgrowth                               0.356684    0.071512   -0.112996
# operatingIncomeGrowth                    0.356684    0.071512   -0.112996
# netIncomeGrowth                          0.351405    0.066771   -0.112525
# epsgrowth                                0.429892    0.134899   -0.103271
# epsdilutedGrowth                         0.429457    0.135849    -0.09966
# weightedAverageSharesGrowth              -0.05458    -0.06048   -0.010148
# weightedAverageSharesDilutedGrowth      -0.053832   -0.061177   -0.014485
# dividendsperShareGrowth                  0.099086    0.120997    3.289513
# operatingCashFlowGrowth                  0.360943    0.112678    0.055254
# freeCashFlowGrowth                       0.398357    0.119085     0.07565
# tenYRevenueGrowthPerShare                 15.5015   17.874571   20.462567
# fiveYRevenueGrowthPerShare               2.964866    4.139103    4.013435
# threeYRevenueGrowthPerShare              0.698435    0.795272    1.575374
# tenYOperatingCFGrowthPerShare           30.531894   53.652831  143.742918
# fiveYOperatingCFGrowthPerShare           3.835804    5.037732    4.328188
# threeYOperatingCFGrowthPerShare          0.817463    0.691577    1.836547
# tenYNetIncomeGrowthPerShare             38.339636  121.373842  417.391305
# fiveYNetIncomeGrowthPerShare             3.216162    6.115139     6.29961
# threeYNetIncomeGrowthPerShare            0.455164    0.620423    1.597716
# tenYShareholdersEquityGrowthPerShare    14.724316    17.78568   21.804161
# fiveYShareholdersEquityGrowthPerShare    1.763443    3.116891    4.597196
# threeYShareholdersEquityGrowthPerShare   0.148379    0.547868    1.540856
# tenYDividendperShareGrowthPerShare            0.0         0.0         0.0
# fiveYDividendperShareGrowthPerShare           0.0         0.0         0.0
# threeYDividendperShareGrowthPerShare     4.284988         0.0         0.0
# receivablesGrowth                        0.114773    0.318686    0.104269
# inventoryGrowth                          0.112743    0.196712    1.230088
# assetGrowth                              0.252934    0.119995    0.175709
# bookValueperShareGrowth                  0.131769   -0.039024    0.055881
# debtGrowth                               0.826378    1.081073         0.0
# rdexpenseGrowth                          0.335375    0.349944    0.323573
# sgaexpensesGrowth                             0.0         0.0         0.0
#
#                                               2012  ...      1994      1993  \
# period                                          FY  ...        FY        FY
# revenueGrowth                             0.445815  ...  0.151905  0.125661
# grossProfitGrowth                         0.566982  ...  -0.19019 -0.126196
# ebitgrowth                                0.634833  ...  3.730743 -0.862976
# operatingIncomeGrowth                     0.634833  ...  3.730743 -0.862976
# netIncomeGrowth                           0.609945  ...  2.581732 -0.836727
# epsgrowth                                 0.591444  ...  2.527168 -0.829497
# epsdilutedGrowth                          0.595015  ...  2.527168 -0.829497
# weightedAverageSharesGrowth               0.011425  ...  0.014595 -0.042426
# weightedAverageSharesDilutedGrowth        0.009299  ...  0.015236 -0.042426
# dividendsperShareGrowth                        0.0  ...  0.002846  0.015094
# operatingCashFlowGrowth                   0.355112  ... -2.113622 -1.748897
# freeCashFlowGrowth                        0.378262  ...   1.65997  -2.27018
# tenYRevenueGrowthPerShare                19.702917  ...  3.937902  3.349289
# fiveYRevenueGrowthPerShare                5.029793  ...   0.87831  1.175928
# threeYRevenueGrowthPerShare               3.092002  ...  0.472965  0.540685
# tenYOperatingCFGrowthPerShare           433.020644  ...       0.0       0.0
# fiveYOperatingCFGrowthPerShare            7.598853  ...  0.569183       0.0
# threeYOperatingCFGrowthPerShare           3.782152  ...  4.791205 -1.737087
# tenYNetIncomeGrowthPerShare             486.668208  ...   4.22471      0.48
# fiveYNetIncomeGrowthPerShare             10.040629  ... -0.262047  -0.75974
# threeYNetIncomeGrowthPerShare             5.989277  ...  0.012541 -0.804233
# tenYShareholdersEquityGrowthPerShare     20.925954  ...  3.462973  2.850021
# fiveYShareholdersEquityGrowthPerShare     6.523406  ...  0.732693  1.242848
# threeYShareholdersEquityGrowthPerShare    3.057345  ...  0.364266   0.50363
# tenYDividendperShareGrowthPerShare             0.0  ...       0.0       0.0
# fiveYDividendperShareGrowthPerShare            0.0  ...  0.214807       0.0
# threeYDividendperShareGrowthPerShare           0.0  ...  0.012596  0.109473
# receivablesGrowth                         0.595289  ...  0.144328  0.271063
# inventoryGrowth                            0.01933  ... -0.277556  1.597138
# assetGrowth                               0.512954  ...  0.025399  0.224377
# bookValueperShareGrowth                    0.52548  ...  0.159207 -0.032559
# debtGrowth                                     0.0  ... -0.275753  3.461789
# rdexpenseGrowth                           0.391931  ...       0.0       0.0
# sgaexpensesGrowth                              0.0  ...       0.0       0.0
#
#                                             1992      1991      1990  \
# period                                        FY        FY        FY
# revenueGrowth                           0.123272  0.135003   0.05193
# grossProfitGrowth                       0.035385   0.01401  0.162454
# ebitgrowth                              0.801252  -0.37177  0.122497
# operatingIncomeGrowth                   0.801252  -0.37177  0.122497
# netIncomeGrowth                         0.712072 -0.347652  0.046035
# epsgrowth                                0.68215 -0.317452  0.067801
# epsdilutedGrowth                         0.68215 -0.317452  0.067801
# weightedAverageSharesGrowth             0.017776 -0.044235  -0.02038
# weightedAverageSharesDilutedGrowth      0.017776 -0.044235  -0.02038
# dividendsperShareGrowth                -0.005292   0.09879  0.091834
# operatingCashFlowGrowth                 5.866356  -0.86648  0.900059
# freeCashFlowGrowth                        8.6875 -1.121147  1.756616
# tenYRevenueGrowthPerShare                2.69984  2.352355  1.822957
# fiveYRevenueGrowthPerShare              1.855012  2.545168  1.822957
# threeYRevenueGrowthPerShare             0.407368  0.677166  1.178359
# tenYOperatingCFGrowthPerShare                0.0       0.0       0.0
# fiveYOperatingCFGrowthPerShare               0.0       0.0       0.0
# threeYOperatingCFGrowthPerShare         0.828011       0.0       0.0
# tenYNetIncomeGrowthPerShare                 7.68      4.16      6.56
# fiveYNetIncomeGrowthPerShare            1.614458      1.15      6.56
# threeYNetIncomeGrowthPerShare           0.225989 -0.162338  1.277108
# tenYShareholdersEquityGrowthPerShare    2.979592  2.271336  1.560485
# fiveYShareholdersEquityGrowthPerShare   1.803494  1.720311  1.560485
# threeYShareholdersEquityGrowthPerShare  0.545026  0.905732  0.803779
# tenYDividendperShareGrowthPerShare           0.0       0.0       0.0
# fiveYDividendperShareGrowthPerShare          0.0       0.0       0.0
# threeYDividendperShareGrowthPerShare    0.193347       0.0       0.0
# receivablesGrowth                       0.198413  0.190707 -0.038976
# inventoryGrowth                         -0.13637  0.889451 -0.252209
# assetGrowth                             0.208982  0.174043  0.084478
# bookValueperShareGrowth                 0.216503  0.277624 -0.005924
# debtGrowth                              0.241588  0.212072  1.158451
# rdexpenseGrowth                              0.0       0.0       0.0
# sgaexpensesGrowth                            0.0       0.0       0.0
#
#                                             1989      1988      1987  \
# period                                        FY        FY        FY
# revenueGrowth                           0.297834  0.529969   0.39918
# grossProfitGrowth                       0.257529  0.503553  0.351728
# ebitgrowth                               0.02257  0.669717  0.358318
# operatingIncomeGrowth                    0.02257  0.669717  0.358318
# netIncomeGrowth                         0.134149   0.84046  0.412338
# epsgrowth                               0.149345  0.855475   0.38333
# epsdilutedGrowth                        0.149345  0.855475   0.38333
# weightedAverageSharesGrowth            -0.013226 -0.008064  0.020967
# weightedAverageSharesDilutedGrowth     -0.013226 -0.008064  0.020967
# dividendsperShareGrowth                      0.0       0.0       0.0
# operatingCashFlowGrowth                      0.0       0.0       0.0
# freeCashFlowGrowth                           0.0       0.0       0.0
# tenYRevenueGrowthPerShare               1.628906   0.99882   0.29591
# fiveYRevenueGrowthPerShare              1.628906   0.99882   0.29591
# threeYRevenueGrowthPerShare              1.78011   0.99882   0.29591
# tenYOperatingCFGrowthPerShare                0.0       0.0       0.0
# fiveYOperatingCFGrowthPerShare               0.0       0.0       0.0
# threeYOperatingCFGrowthPerShare              0.0       0.0       0.0
# tenYNetIncomeGrowthPerShare                 6.08      5.16      2.32
# fiveYNetIncomeGrowthPerShare                6.08      5.16      2.32
# threeYNetIncomeGrowthPerShare               1.95      5.16      2.32
# tenYShareholdersEquityGrowthPerShare    1.575744  0.716577  0.419511
# fiveYShareholdersEquityGrowthPerShare   1.575744  0.716577  0.419511
# threeYShareholdersEquityGrowthPerShare  1.141884  0.716577  0.419511
# tenYDividendperShareGrowthPerShare           0.0       0.0       0.0
# fiveYDividendperShareGrowthPerShare          0.0       0.0       0.0
# threeYDividendperShareGrowthPerShare         0.0       0.0       0.0
# receivablesGrowth                       0.241077  0.574951  0.541619
# inventoryGrowth                         0.030119  1.043844  1.077277
# assetGrowth                             0.317852  0.408823  0.273942
# bookValueperShareGrowth                 0.500247       0.0       0.0
# debtGrowth                             -0.819683       0.0       0.0
# rdexpenseGrowth                              0.0       0.0       0.0
# sgaexpensesGrowth                            0.0       0.0       0.0
#
#                                             1986 1985
# period                                        FY   FY
# revenueGrowth                          -0.008549  0.0
# grossProfitGrowth                       0.260715  0.0
# ebitgrowth                              0.856755  0.0
# operatingIncomeGrowth                   0.856755  0.0
# netIncomeGrowth                          1.51634  0.0
# epsgrowth                                1.40009  0.0
# epsdilutedGrowth                         1.40009  0.0
# weightedAverageSharesGrowth             0.048475  0.0
# weightedAverageSharesDilutedGrowth      0.048475  0.0
# dividendsperShareGrowth                      0.0  0.0
# operatingCashFlowGrowth                      0.0  0.0
# freeCashFlowGrowth                           0.0  0.0
# tenYRevenueGrowthPerShare              -0.054388  0.0
# fiveYRevenueGrowthPerShare             -0.054388  0.0
# threeYRevenueGrowthPerShare            -0.054388  0.0
# tenYOperatingCFGrowthPerShare                0.0  0.0
# fiveYOperatingCFGrowthPerShare               0.0  0.0
# threeYOperatingCFGrowthPerShare              0.0  0.0
# tenYNetIncomeGrowthPerShare                  1.4  0.0
# fiveYNetIncomeGrowthPerShare                 1.4  0.0
# threeYNetIncomeGrowthPerShare                1.4  0.0
# tenYShareholdersEquityGrowthPerShare     0.20256  0.0
# fiveYShareholdersEquityGrowthPerShare    0.20256  0.0
# threeYShareholdersEquityGrowthPerShare   0.20256  0.0
# tenYDividendperShareGrowthPerShare           0.0  0.0
# fiveYDividendperShareGrowthPerShare          0.0  0.0
# threeYDividendperShareGrowthPerShare         0.0  0.0
# receivablesGrowth                       0.194823  0.0
# inventoryGrowth                        -0.349102  0.0
# assetGrowth                             0.239158  0.0
# bookValueperShareGrowth                      0.0  0.0
# debtGrowth                                   0.0  0.0
# rdexpenseGrowth                              0.0  0.0
# sgaexpensesGrowth                            0.0  0.0
#
# [35 rows x 37 columns]
