# %%
# %run stock_screener.ipynb
# Out:
# [Info] loading page [##############################] 1/1
# The total return for CLFD is 9.805007457733028
# The total return for CVLG is -5.04058265686016
# The total return for GLP is -4.62137269973727
# The total return for MGPI is -1.0735378265378848
# The total return for MUSA is 43.84957122802766
# The total return for OTTR is 6.193424224853783
# The total return for SRTS is 1.0690000057220317
# The total return for USAK is 7.844998359680155

# %%
# %run macd.ipynb
# Out:
# The total return for CLFD is 3.4650058746344303####] 1/1
# The total return for CVLG is -0.7447776794434868
# The total return for GLP is -5.025489807129246
# The total return for MGPI is 37.46623611450188
# The total return for MUSA is 31.964752197265778
# The total return for OTTR is 7.611608505249046
# The total return for SRTS is 1.4380002021788796
# The total return for USAK is 12.44999599456802

# %%
# %run stock_screener_2.ipynb
# Out:
# [*********************100%***********************]  8 of 8 completed
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 100)           40800
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 25)                2525
#
#  dense_1 (Dense)             (None, 1)                 26
#
# ...
# Total params: 123,751
# Trainable params: 123,751
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 947/947 [==============================] - 12s 11ms/step - loss: 5.5373e-04
# Epoch 2/3
# 947/947 [==============================] - 11s 11ms/step - loss: 3.3247e-04
# Epoch 3/3
# ...
# 8/8 [==============================] - 1s 17ms/step
# Model: "sequential_1"
# _________________________________________________________________
# ...
